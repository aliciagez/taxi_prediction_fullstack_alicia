# %% [markdown]
# # Model Development

# %% [markdown]
# ## Logistic regression

# %%
from taxipred.utils.constants import TAXI_REMOVED_NA
import pandas as pd 
df = pd.read_csv(TAXI_REMOVED_NA)

df.head(5)
# Out:
#    Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0             19.35                3       3.56         0.80             0.32
# 1             36.87                1       2.70         1.21             0.15
# 2             30.33                4       3.48         0.51             0.15
# 3              8.64                2       2.55         1.71             0.48
# 4             41.79                3       4.60         1.77             0.11
#
#    Trip_Duration_Minutes  Trip_Price  Time_of_Day_Afternoon  \
# 0                  53.82     36.2624                      0
# 1                  37.27     52.9032                      0
# 2                 116.81     36.4698                      0
# 3                  89.33     60.2028                      1
# 4                  86.95     88.1328                      0
#
#    Time_of_Day_Evening  Time_of_Day_Morning  Time_of_Day_Night  \
# 0                    0                    1                  0
# 1                    1                    0                  0
# 2                    1                    0                  0
# 3                    0                    0                  0
# 4                    0                    0                  1
#
#    Day_of_Week_Weekday  Day_of_Week_Weekend
# 0                    1                    0
# 1                    0                    1
# 2                    1                    0
# 3                    0                    1
# 4                    0                    1

# %%
y=df["Trip_Price"]
y.head()
# Out:
# 0    36.2624
# 1    52.9032
# 2    36.4698
# 3    60.2028
# 4    88.1328
# Name: Trip_Price, dtype: float64

# %%
X = df.drop("Trip_Price", axis=1)
X.head()
# Out:
#    Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0             19.35                3       3.56         0.80             0.32
# 1             36.87                1       2.70         1.21             0.15
# 2             30.33                4       3.48         0.51             0.15
# 3              8.64                2       2.55         1.71             0.48
# 4             41.79                3       4.60         1.77             0.11
#
#    Trip_Duration_Minutes  Time_of_Day_Afternoon  Time_of_Day_Evening  \
# 0                  53.82                      0                    0
# 1                  37.27                      0                    1
# 2                 116.81                      0                    1
# 3                  89.33                      1                    0
# 4                  86.95                      0                    0
#
#    Time_of_Day_Morning  Time_of_Day_Night  Day_of_Week_Weekday  \
# 0                    1                  0                    1
# 1                    0                  0                    0
# 2                    0                  0                    1
# 3                    0                  0                    0
# 4                    0                  1                    0
#
#    Day_of_Week_Weekend
# 0                    0
# 1                    1
# 2                    0
# 3                    1
# 4                    1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

print(f"{X_train.shape = }")
print(f"{X_test.shape = }")
print(f"{y_train.shape = }")
print(f"{y_test.shape = }")
# Out:
# X_train.shape = (456, 12)
# X_test.shape = (225, 12)
# y_train.shape = (456,)
# y_test.shape = (225,)

# %%
X_train.head(5)
# Out:
#      Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  \
# 50              38.79                2       3.95         1.88
# 583             24.13                1       3.37         1.92
# 220             42.92                3       4.66         1.05
# 166             19.87                1       4.40         1.34
# 206             41.96                4       2.21         1.22
#
#      Per_Minute_Rate  Trip_Duration_Minutes  Time_of_Day_Afternoon  \
# 50              0.33                  82.93                      1
# 583             0.31                  23.71                      1
# 220             0.34                  62.85                      0
# 166             0.38                  27.60                      1
# 206             0.19                  80.28                      1
#
#      Time_of_Day_Evening  Time_of_Day_Morning  Time_of_Day_Night  \
# 50                     0                    0                  0
# 583                    0                    0                  0
# 220                    0                    1                  0
# 166                    0                    0                  0
# 206                    0                    0                  0
#
#      Day_of_Week_Weekday  Day_of_Week_Weekend
# 50                     1                    0
# 583                    1                    0
# 220                    1                    0
# 166                    0                    1
# 206                    0                    1

# %%
y_train.head()
# Out:
# 50     104.2421
# 583     57.0497
# 220     71.0950
# 166     41.5138
# 206     68.6544
# Name: Trip_Price, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
scale.fit(X_train)
scaled_X_train = scale.transform(X_train)
scaled_X_test = scale.transform(X_test)

scaled_X_test.shape, scaled_X_train.shape
# Out:
# ((225, 12), (456, 12))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(scaled_X_train,y_train)
model.coef_, model.intercept_
# Out:
# (array([17.24119925,  0.26363852,  0.80812695,  9.91139922,  6.99747567,
#          9.01141551,  0.74996096,  0.45185149,  1.28022299,  0.18067697,
#         -0.14087748,  0.24071933]),
#  np.float64(51.58155087719298))

# %%
test_sample_1 = scaled_X_test[0].reshape(1,-1)
test_sample_2 = y_test.values[0]
test_sample_1, test_sample_2
# Out:
# (array([[ 0.04224297, -0.46813859, -1.1786586 , -0.86088091, -0.65018035,
#           1.57416358, -0.74942901,  1.98910074, -0.62130366, -0.34299717,
#           0.75658033, -0.68281618]]),
#  np.float64(48.4142))

# %%
pred_y = model.predict(scaled_X_test)
pred_y
# Out:
# array([ 51.54563623,  75.51489813,  45.1503705 ,  33.70369133,
#         53.07960191,  55.63080739,  82.9949429 ,  45.40144168,
#         59.00081089,  25.67106867,  -0.35383714,  64.84141239,
#         63.86179578,  19.92110176,  23.27723097,  64.54541785,
#         61.48877961,  73.89497814,  45.91761931,  64.8980399 ,
#         53.19030432,  73.87430419,  84.41566793,  39.38027491,
#         40.16524793,  44.61216531,  84.88841954,  62.1695736 ,
#         42.70933045,  87.4744498 ,  89.71172593,  23.30330499,
#         16.8807531 ,  22.87812785,  79.6616771 ,  60.69482129,
#         52.85733989,  49.86148747,  68.50292175,  70.00417191,
#         15.22858544,  44.94792964,  87.5062968 ,  59.86147002,
#          3.90519576,  32.25257687,  31.58677465,  70.50293317,
#         50.19270619,  19.26470498,  33.99632798,  73.05340356,
#         82.23141277,  73.2508307 ,  48.30907252,  30.99416699,
#         60.5759023 ,  25.43659618,  63.11266846,  50.29595701,
#         -0.43328099,  39.03111412,  69.83268264,  69.55345565,
#         39.84304885,  56.97390438,  45.8356677 ,  74.13438845,
#         42.48056593,  37.6348969 ,  96.75625249,  78.56663792,
#         91.23216092,  21.34758065,  67.7848012 ,  37.98943327,
#         59.79145358,  72.46209396,  57.6622947 ,  50.37388192,
#         65.49136952,  38.8772824 ,   7.2875574 ,  51.79906426,
#         46.86079221,  41.03656924,   6.67067282,  65.9941117 ,
#         45.82838056,  55.33749154,  76.97819277,  43.87475933,
#         50.50506805,  70.24567523,  22.1363253 ,  48.41762568,
#         80.74617716,  98.13395145,  69.75056325,  80.00841575,
#         59.11583118,  45.45336138,  17.37915429,  54.4645925 ,
#         27.45527097,  76.01780175,  84.08570332,  49.32422291,
#          6.6083039 ,  82.49866601,  40.17138403,  64.32696466,
#         51.4172748 ,  37.41001743,  51.61068195,  83.63830189,
#         23.72745835,  44.68667962,  33.50408442,  77.61173381,
#         42.28218723,  85.35248375,  30.26845918,  30.70908375,
#         12.55385755,  54.63896725,  61.60153757,  19.72961391,
#         30.31982855,  39.41448353,  18.16854656,  89.59700586,
#         76.77903742,  45.98706441,  53.21046751,  38.62484464,
#         57.18580777,  43.87238365,  44.51331558,  35.70524614,
#         -4.06051761,  64.75473333,  73.84443292,  69.86345158,
#         73.19969193,  27.7991401 ,  96.19709529,  83.06735928,
#         28.32386797,  32.91296529,  61.66579873,  39.0935957 ,
#         62.29467337,  70.77778967,  43.067207  ,  37.93142057,
#         93.3077974 ,  54.69399074,  66.67536401,  67.25365455,
#         74.68305482,  68.5358968 ,  83.85125462,  51.03922715,
#         31.20643428,  43.35468855,  71.27767637,  45.65312691,
#         65.29196363,  16.58088456,  63.18223561,  58.58398713,
#        103.14373277,  50.05424103,  75.41338562,  48.54488348,
#         49.04781447,   7.84133368,  88.80698607,  42.68426753,
#         54.51475055,  33.47377983,  67.67277874,  73.0029601 ,
#         70.33559795,  16.42721743,  81.03282586,  25.35673319,
#         71.49085998,  67.88146729,  68.4140542 ,  28.01389429,
#         55.97359023,  83.45237546,  22.36084305,  46.50551077,
#         33.10316018,  25.95885666,  51.95562252,  58.56696575,
#         26.02358098,  43.83339309,  61.22270558,  34.78651916,
#         54.46441645,  49.14836816,  38.59024147,   0.30176903,
#         56.57978312,  29.95601822,  24.72750867,  60.28862787,
#         32.71059951,  55.20333214,  49.82059242,  29.53725006,
#         48.28095471,  80.38932121,  49.13624485,  33.20969933,
#         52.59260817,  62.29483513,  45.77001053,  37.18460196,
#         56.15614327])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mean_ab_er = mean_absolute_error(y_test,pred_y)
mean_sq_er = mean_squared_error(y_test,pred_y)
root_me_sq_er = np.sqrt(mean_sq_er)

print(f"Mean absolut error {mean_ab_er}, Mean squarerd error {mean_sq_er}, Root Mean squared error {root_me_sq_er}")
# Out:
# Mean absolut error 5.396264816169342, Mean squarerd error 46.9322216032423, Root Mean squared error 6.850709569325085

# %% [markdown]
# comparing with baseline (got from LLM)

# %%
base_line = np.mean(y_test)
base_with_mae = mean_absolute_error(y_test, [base_line]*len(y_test))
base_line, base_with_mae
# Out:
# (np.float64(51.76569466666667), 19.48548848592593)
