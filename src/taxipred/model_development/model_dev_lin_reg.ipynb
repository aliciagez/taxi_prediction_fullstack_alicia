# %% [markdown]
# # Model Development

# %% [markdown]
# ## Logistic regression

# %%
from taxipred.utils.constants import TAXI_REMOVED_NA
import pandas as pd 
df = pd.read_csv(TAXI_REMOVED_NA)

df.head(5)
# Out:
#    Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0             19.35                3       3.56         0.80             0.32
# 1             36.87                1       2.70         1.21             0.15
# 2             30.33                4       3.48         0.51             0.15
# 3              8.64                2       2.55         1.71             0.48
# 4             41.79                3       4.60         1.77             0.11
#
#    Trip_Duration_Minutes  Trip_Price  Time_of_Day_Afternoon  \
# 0                  53.82     36.2624                      0
# 1                  37.27     52.9032                      0
# 2                 116.81     36.4698                      0
# 3                  89.33     60.2028                      1
# 4                  86.95     88.1328                      0
#
#    Time_of_Day_Evening  Time_of_Day_Morning  Time_of_Day_Night  \
# 0                    0                    1                  0
# 1                    1                    0                  0
# 2                    1                    0                  0
# 3                    0                    0                  0
# 4                    0                    0                  1
#
#    Day_of_Week_Weekday  Day_of_Week_Weekend
# 0                    1                    0
# 1                    0                    1
# 2                    1                    0
# 3                    0                    1
# 4                    0                    1

# %%
y=df["Trip_Price"]
y.head()
# Out:
# 0    36.2624
# 1    52.9032
# 2    36.4698
# 3    60.2028
# 4    88.1328
# Name: Trip_Price, dtype: float64

# %%
X = df.drop("Trip_Price", axis=1)
X.head()
# Out:
#    Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0             19.35                3       3.56         0.80             0.32
# 1             36.87                1       2.70         1.21             0.15
# 2             30.33                4       3.48         0.51             0.15
# 3              8.64                2       2.55         1.71             0.48
# 4             41.79                3       4.60         1.77             0.11
#
#    Trip_Duration_Minutes  Time_of_Day_Afternoon  Time_of_Day_Evening  \
# 0                  53.82                      0                    0
# 1                  37.27                      0                    1
# 2                 116.81                      0                    1
# 3                  89.33                      1                    0
# 4                  86.95                      0                    0
#
#    Time_of_Day_Morning  Time_of_Day_Night  Day_of_Week_Weekday  \
# 0                    1                  0                    1
# 1                    0                  0                    0
# 2                    0                  0                    1
# 3                    0                  0                    0
# 4                    0                  1                    0
#
#    Day_of_Week_Weekend
# 0                    0
# 1                    1
# 2                    0
# 3                    1
# 4                    1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

print(f"{X_train.shape = }")
print(f"{X_test.shape = }")
print(f"{y_train.shape = }")
print(f"{y_test.shape = }")
# Out:
# X_train.shape = (421, 12)
# X_test.shape = (208, 12)
# y_train.shape = (421,)
# y_test.shape = (208,)

# %%
X_train.head(5)
# Out:
#      Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  \
# 146             45.83                4       4.50         1.36
# 550             33.29                3       4.48         1.10
# 405             37.53                4       2.19         1.84
# 123              5.97                4       4.69         1.89
# 222             47.13                4       4.15         1.30
#
#      Per_Minute_Rate  Trip_Duration_Minutes  Time_of_Day_Afternoon  \
# 146             0.39                  54.66                      0
# 550             0.19                  52.09                      1
# 405             0.48                  62.05                      1
# 123             0.32                  90.57                      1
# 222             0.23                   6.47                      0
#
#      Time_of_Day_Evening  Time_of_Day_Morning  Time_of_Day_Night  \
# 146                    1                    0                  0
# 550                    0                    0                  0
# 405                    0                    0                  0
# 123                    0                    0                  0
# 222                    1                    0                  0
#
#      Day_of_Week_Weekday  Day_of_Week_Weekend
# 146                    1                    0
# 550                    1                    0
# 405                    1                    0
# 123                    1                    0
# 222                    1                    0

# %%
y_train.head()
# Out:
# 146     88.1462
# 550     50.9961
# 405    101.0292
# 123     44.9557
# 222     66.9071
# Name: Trip_Price, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
scale.fit(X_train)
scaled_X_train = scale.transform(X_train)
scaled_X_test = scale.transform(X_test)

scaled_X_test.shape, scaled_X_train.shape
# Out:
# ((208, 12), (421, 12))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(scaled_X_train,y_train)
model.coef_, model.intercept_
# Out:
# (array([ 3.60899958e+01, -2.39776332e-02,  1.13136677e+00,  1.03088425e+01,
#          6.60866988e+00,  9.81126036e+00,  1.24760497e-01, -2.80039999e-01,
#          6.27184488e-01, -7.15798942e-01, -2.99436164e-01,  2.99436164e-01]),
#  np.float64(56.3768369816603))

# %%
test_sample_1 = scaled_X_test[0].reshape(1,-1)
test_sample_2 = y_test.values[0]
test_sample_1, test_sample_2
# Out:
# (array([[-0.02601053, -1.37401063, -0.89786848,  0.29947622, -0.868739  ,
#          -0.26871171, -0.80282704, -0.53982501,  1.6312172 , -0.35023801,
#          -1.47153441,  1.47153441]]),
#  np.float64(47.8069))

# %%
pred_y = model.predict(scaled_X_test)
pred_y
# Out:
# array([ 5.13709342e+01,  7.33148705e+01,  7.87855700e+01,  7.98861426e+01,
#         1.06450535e+02,  2.35595202e+01,  2.10577781e+01,  3.49401979e+01,
#         9.89215226e+01,  1.06167256e+02,  5.10874777e+01, -3.68654059e-01,
#         3.59712610e+01,  4.57989980e+01, -5.49173529e+00,  2.76924812e+02,
#         4.87990097e+01,  4.42162428e+01,  3.78991572e+01,  1.01831400e+02,
#         1.04470652e+02,  8.34309963e+01,  6.41500878e+01,  9.87681413e+01,
#         4.81782546e+01,  3.36819044e+01,  3.70374167e+01,  6.06744397e+01,
#         9.36525870e+01,  5.83169837e+01,  7.48064267e+01,  6.89618893e+00,
#         6.26770425e+01,  6.64350747e+01,  3.82236081e+01,  7.05412402e+01,
#         3.32159514e+01,  4.38250276e+01,  7.40024663e+01,  4.50861578e+01,
#         1.07657397e+02,  3.63344607e+01,  7.62241119e+01,  8.86162926e+01,
#         5.67366887e+01,  9.76653649e+01,  7.64498662e+01,  2.34976688e+01,
#         7.30065092e+01,  7.62663481e+01,  6.57955369e+01,  3.29181538e+01,
#         2.74350054e+02, -2.39694664e+01,  2.02873151e+01,  3.90942996e+01,
#         5.16259346e+01,  7.98919796e+01,  1.10330337e+01,  4.52956428e+01,
#         5.06208815e+01,  8.31643491e+01,  8.47953631e+01,  9.25263741e+01,
#         6.02626821e+01,  5.59311806e+01,  7.61393407e+01,  3.96418733e+01,
#         9.98493622e+01,  7.05372094e+01,  3.19475933e+01,  2.26880392e+02,
#         6.03931696e+01,  5.67065044e+01,  2.95375664e+01,  4.84505278e+01,
#         8.98632129e+01,  8.13005537e+01,  5.22750868e+01,  3.42535329e+01,
#         5.34168596e+01,  3.13176968e+01,  5.81603163e+01,  1.96500072e+02,
#         1.97080856e+01,  2.20232722e+00,  2.13156661e+01,  4.82171162e+01,
#         8.29434481e+01,  2.99126051e+01,  2.02763736e+01,  6.64480972e+01,
#         1.01701603e+02,  1.64499546e+01,  6.70415529e+01,  3.64507633e+01,
#         6.49949198e+01,  5.19024915e+01,  5.50577586e+01,  6.68916227e+01,
#         7.83650170e+01,  2.46262053e+01,  7.55802269e+01,  5.91114490e+01,
#        -1.16585765e+01,  5.81512282e+01,  1.67788177e+01,  1.25575152e+01,
#         5.31712916e+01,  6.51280346e+01,  1.00935041e+02,  7.27532958e+01,
#         5.77879159e+01,  9.73953389e+01,  3.74761674e+01,  5.34019480e+01,
#         2.10283043e+01,  3.59082967e+01,  1.33855734e+01,  6.63071269e+01,
#         8.46218729e+01,  6.83764572e+01,  8.50494675e+01,  1.13836167e+02,
#         3.54979879e+01,  8.27908254e+01,  1.51336218e+01,  6.16200336e+01,
#         4.63335132e+01,  5.92299397e+01,  3.34706093e+01,  3.62596982e+01,
#         7.53133240e+01,  8.93804072e+01,  8.67483103e+01,  6.65583583e+01,
#         8.37105894e+01,  7.13581461e+01,  1.22762216e+02,  7.70054756e+01,
#         9.85933432e+00,  5.33924090e+01,  7.07190872e+01,  9.24435386e+01,
#         6.01448011e+01,  5.74815711e+01,  5.61402333e+01,  7.36827309e+01,
#         1.07903830e+02,  7.19774875e-01,  7.07296468e+00,  4.20225664e+01,
#         3.64499293e+01,  5.51566074e+01,  8.98771480e+01,  2.57036654e+01,
#         2.51958859e+01,  7.31248556e+01,  1.04416571e+02,  2.12252843e+01,
#         1.54518409e+01,  5.74638532e+01,  4.94265906e+01,  6.25467646e+01,
#         2.82002260e+01,  1.71725146e+01,  2.95357441e+01,  4.41573828e+01,
#         3.83137420e+01,  1.29551022e-01,  6.88467093e+01,  3.93083152e+01,
#         9.63495264e+01,  1.90322374e+02,  5.26393435e+01,  4.62539157e+01,
#         6.33833404e+01,  7.00815080e+01,  3.86460422e+01,  4.47139551e+01,
#         3.21916806e+01,  2.68866841e+02,  5.55141345e+01,  5.03987999e+01,
#         1.08005425e+02,  3.04859100e+01,  7.90161424e+01,  7.69619616e+01,
#         7.63000781e+01,  2.21089132e+01,  3.42540962e+01,  6.58591766e+01,
#         2.15829631e+01,  8.65845742e+01,  4.51704284e+01,  1.11647410e+02,
#         6.01392590e+01,  1.00986902e+02,  8.03052853e+01,  3.86973901e+01,
#         5.57982474e+01,  4.67800947e+01,  3.86791734e+01,  6.50300289e+01,
#         1.36629846e+01,  7.49562460e+01,  3.64146307e+01,  1.02770400e+01])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mean_ab_er = mean_absolute_error(y_test,pred_y)
mean_sq_er = mean_squared_error(y_test,pred_y)
root_me_sq_er = np.sqrt(mean_sq_er)

print(f"Mean absolut error {mean_ab_er}, Mean squarerd error {mean_sq_er}, Root Mean squared error {root_me_sq_er}")
# Out:
# Mean absolut error 8.155224811572584, Mean squarerd error 153.72533488136466, Root Mean squared error 12.398602134166765
